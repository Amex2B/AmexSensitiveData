# %%
import os
import pandas as pd

# %%
filepath = os.path.join(os.getcwd(), 'data', 'extracted_tel_numbers_english_updated.csv')

# Read the CSV file using pandas
df = pd.read_csv(filepath)

# %%
# Use the same rows as those in Shrieyaa's mini df to check if the updated regex algorithm works
sample_df = df[448:548]

# %%
# sample_df = sample_df.drop('Unnamed: 0', axis=1)
sample_df
# Out:
#      Unnamed: 0                                      unmasked_text  \
# 448         448  Got some exciting findings for individuals wit...
# 449         449  Name Simonis, your cognitive therapy session i...
# 450         450  Medical intervention and occupational therapy ...
# 451         451  Looking for a therapy session before 6 AM. Liv...
# 452         452  Emergency meeting announced for Accounts assoc...
# ..          ...                                                ...
# 543         543  Patient Fredrick with insurance account 226610...
# 544         544  We received your request Jaleel. We'll get in ...
# 545         545  Hi, just signed up for a new start-up venture....
# 546         546  Frederic_Cormier14, we noticed you missed our ...
# 547         547  Urgent: Ignatius Kyle is responsible for Turco...
#
#                                            masked_text       phone_number  \
# 448  Got some exciting findings for individuals wit...        05196 04711
# 449  [FIRSTNAME_1] [LASTNAME_1], your cognitive the...      1063 690.6267
# 450  Medical intervention and occupational therapy ...   +40-724-062 4764
# 451  Looking for a therapy session before [TIME_1]....        03816-26306
# 452  Emergency meeting announced for [JOBAREA_1] as...   +94.476-548.6102
# ..                                                 ...                ...
# 543  Patient [FIRSTNAME_1] with insurance account [...  +736 435 268.6135
# 544  We received your request [FIRSTNAME_1]. We'll ...       048 782 9867
# 545  Hi, just signed up for a new start-up venture....     (28)-5333-1243
# 546  [USERNAME_1], we noticed you missed our last s...     (83).1657 1303
# 547  Urgent: [FIRSTNAME_1] [MIDDLENAME_1] is respon...     01-93.83 26-27
#
#     target
# 448      O
# 449    TEL
# 450    TEL
# 451      O
# 452    TEL
# ..     ...
# 543    TEL
# 544    TEL
# 545      O
# 546      O
# 547      O
#
# [100 rows x 5 columns]

# %%
filepath = os.path.join(os.getcwd(), 'data', 'joy_mini_df_tel.csv')
sample_df.to_csv(filepath)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Imported the dataset
from datasets import load_dataset
from datasets import Dataset

train_set1=load_dataset('ai4privacy/pii-masking-300k', split='train')
val_set=load_dataset('ai4privacy/pii-masking-300k', split='validation')

filepath = os.path.join(os.getcwd(), '..', 'data', 'maker_day_shrieyaa_stella_mini200_df.csv')
train_df2 = pd.read_csv(filepath)
train_set2 = Dataset.from_pandas(train_df2)

# %%
# Inspect the dataset
print(type(train_set1))
print(train_set1.shape)
val_set.shape
# Out:
# <class 'datasets.arrow_dataset.Dataset'>
# (177677, 9)
# (47728, 9)

# %%
import random
# Select 100 random indices
# random_indices = random.sample(range(len(train_set1)), 10)
random_indices = random.sample(range(len(train_set2)), 10)

# Get the random samples
random_samples = train_set2.select(random_indices)

print(random_samples)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 7
#       4 random_indices = random.sample(range(len(train_set1)), 10)
#       6 # Get the random samples
# ----> 7 random_samples = train_set2.select(random_indices)
#       9 print(random_samples)
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\fingerprint.py:482, in fingerprint_transform.<locals>._fingerprint.<locals>.wrapper(*args, **kwargs)
#     478             validate_fingerprint(kwargs[fingerprint_name])
#     480 # Call actual function
# --> 482 out = func(dataset, *args, **kwargs)
#     484 # Update fingerprint of in-place transforms + update in-place history of transforms
#     486 if inplace:  # update after calling func so that the fingerprint doesn't change if the function fails
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:3963, in Dataset.select(self, indices, keep_in_memory, indices_cache_file_name, writer_batch_size, new_fingerprint)
#    3960             return self._select_contiguous(start, length, new_fingerprint=new_fingerprint)
#    3962 # If not contiguous, we need to create a new indices mapping
# -> 3963 return self._select_with_indices_mapping(
#    3964     indices,
#    3965     keep_in_memory=keep_in_memory,
#    3966     indices_cache_file_name=indices_cache_file_name,
#    3967     writer_batch_size=writer_batch_size,
#    3968     new_fingerprint=new_fingerprint,
#    3969 )
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\fingerprint.py:482, in fingerprint_transform.<locals>._fingerprint.<locals>.wrapper(*args, **kwargs)
#     478             validate_fingerprint(kwargs[fingerprint_name])
#     480 # Call actual function
# --> 482 out = func(dataset, *args, **kwargs)
#     484 # Update fingerprint of in-place transforms + update in-place history of transforms
#     486 if inplace:  # update after calling func so that the fingerprint doesn't change if the function fails
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:4094, in Dataset._select_with_indices_mapping(self, indices, keep_in_memory, indices_cache_file_name, writer_batch_size, new_fingerprint)
#    4092 size = len(self)
#    4093 if indices:
# -> 4094     _check_valid_indices_value(int(max(indices)), size=size)
#    4095     _check_valid_indices_value(int(min(indices)), size=size)
#    4096 else:
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:659, in _check_valid_indices_value(index, size)
#     657 def _check_valid_indices_value(index, size):
#     658     if (index < 0 and index + size < 0) or (index >= size):
# --> 659         raise IndexError(f"Index {index} out of range for dataset of size {size}.")
#
# IndexError: Index 154472 out of range for dataset of size 200.

# %%
import random
# Select 100 random indices
# random_indices = random.sample(range(len(train_set1)), 10)
random_indices = random.sample(range(len(train_set2)), 10)

# Get the random samples
random_samples = train_set2.select(random_indices)

print(random_samples)
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'unmasked_text', 'masked_text'],
#     num_rows: 10
# })

# %%
# Load model directly
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('lakshyakh93/deberta_finetuned_pii')
tokenizer.vocab
# Out:
# {'ĠAc': 6208,
#  'ĠRedmond': 29687,
#  'ribed': 33273,
#  'Desc': 47066,
#  'Alexander': 33409,
#  'ĠAuschwitz': 36531,
#  'uther': 36916,
#  'Ġsize': 1836,
#  'Ġcontractors': 9617,
#  'olesc': 42612,
#  'IDES': 42635,
#  'Ġmitochond': 44783,
#  'ĠTell': 11378,
#  'urst': 30141,
#  'ados': 6510,
#  'çİĭ': 49548,
#  'Ġblown': 12315,
#  'ĠBull': 6518,
#  'Ġsooner': 10027,
#  'Ġmasses': 15444,
#  'ENCE': 13471,
#  'Ġkilograms': 23096,
#  'Ġdisturbances': 34614,
#  'Jess': 44898,
#  'irts': 24546,
#  'ĠMovie': 13131,
#  'ĠTheatre': 5132,
#  'ĠAbsent': 41922,
#  'Ġaligned': 14485,
#  'Ġlowered': 8206,
#  'jit': 17076,
#  'ĠCavs': 14427,
#  'ĠWest': 580,
#  'Ġenacted': 14673,
#  'ĠTimber': 19440,
#  'Ġupstream': 21561,
#  'FIR': 39679,
#  'irie': 36181,
#  'Network': 40283,
#  'Ġwife': 1141,
#  'Ġswollen': 27722,
#  'ĠEmber': 42239,
#  'Ġconfir': 48178,
#  'Ġstd': 49008,
#  'byss': 49889,
#  'ĠFat': 11289,
#  'Ġfunctioning': 13838,
#  'Ġ++': 48793,
#  'Ġbuckets': 26598,
#  'Ġruler': 23586,
#  'ĠUndead': 48413,
#  'Ġtrivia': 35317,
#  'Ġintersection': 8088,
#  'Ġnovice': 32219,
#  'THING': 42965,
#  'ĠCatalyst': 34701,
#  'Ġspherical': 44787,
#  'icing': 16483,
#  'Ġ45': 2248,
#  'IG': 5969,
#  'ĠSpec': 33534,
#  'Ġmoon': 6950,
#  'Meg': 40555,
#  'Ġadaptation': 14082,
#  'Ġconference': 1019,
#  'ards': 5954,
#  'Ġlegislature': 9251,
#  'ĠSaddam': 29315,
#  'ĠReserve': 3965,
#  'ĠDale': 11302,
#  'ĠBrewing': 16922,
#  'Ġvintage': 12669,
#  'Ġdevils': 45412,
#  'Ġgenerated': 5129,
#  'brow': 39457,
#  'Ġcurtain': 23416,
#  'photos': 40259,
#  'Ġcalled': 373,
#  'Ġpeers': 6763,
#  'Ġwaved': 21017,
#  'Ġsuff': 15544,
#  'Ġdisadvantaged': 24341,
#  'Ġâĺħ': 41270,
#  'itches': 30312,
#  'western': 16507,
#  'Ġmore': 55,
#  'ĠZup': 47968,
#  'Ġjunk': 15163,
#  'Ġdeny': 7631,
#  'ĠGriffin': 9192,
#  'Ġanalyze': 11526,
#  'SY': 21134,
#  'ĠWhats': 35415,
#  'ĠLLC': 2291,
#  'Ġoneself': 36158,
#  'Ġfits': 10698,
#  'Ġdonor': 12125,
#  'ery': 4270,
#  'Ġcoax': 32698,
#  'ĠBurma': 35044,
#  'ĠDinner': 18171,
#  'Ġinfections': 11341,
#  'Ġobsessive': 36003,
#  '537': 39155,
#  'Ġworry': 4022,
#  'Ġenrol': 23716,
#  'Ġpotent': 16139,
#  'asking': 30954,
#  'ĠHust': 31112,
#  'Ġacc': 7678,
#  'commit': 42721,
#  'Ġgallon': 17126,
#  'åı': 45262,
#  'interrupted': 46500,
#  'Ġvisits': 5695,
#  'Ġpleas': 19518,
#  'kit': 23199,
#  'Ġstroke': 8579,
#  'ĠFlores': 17318,
#  'ĠAnge': 29199,
#  'CENT': 31152,
#  'Ġdownfall': 27849,
#  'Ġrelates': 16009,
#  'Ġsynerg': 21501,
#  'Ġbattle': 2168,
#  'ĠRoses': 32808,
#  'Ġdismissive': 37890,
#  'Ġdifferent': 430,
#  'Ġ333': 30242,
#  'Ġdepletion': 39309,
#  'Ġrou': 16799,
#  'Ġheadlines': 6337,
#  'Ġdecreased': 8065,
#  'Veh': 45691,
#  'Dro': 46755,
#  'Ġstriking': 5690,
#  'Ġindu': 48452,
#  'Ó': 49013,
#  'porter': 35802,
#  'Ġç': 48283,
#  'Cra': 47137,
#  'Ġvalued': 2328,
#  'ĠTelecommunications': 31121,
#  'irming': 20277,
#  'PORT': 20275,
#  'cloud': 26601,
#  'ĠPul': 13006,
#  'ett': 2645,
#  'Ġmillisec': 47044,
#  'ĠJets': 6261,
#  'lich': 9182,
#  'ainer': 22022,
#  'Captain': 35645,
#  'Ġconcentrated': 15450,
#  'hetic': 18667,
#  'Ġdirectives': 29256,
#  'ophe': 32232,
#  'Ġfunnel': 23662,
#  '================': 46945,
#  'Oh': 7516,
#  'aida': 36567,
#  'ĠE': 381,
#  'ione': 8525,
#  'shirt': 8674,
#  'Ġredef': 28557,
#  'certain': 31097,
#  'Ġcoefficient': 45979,
#  'bul': 21343,
#  'Ġfunky': 33205,
#  'ĠPressure': 26324,
#  'Disney': 37711,
#  'ĠTheNitromeFan': 50233,
#  'bool': 46787,
#  'Ġsnacks': 14967,
#  'ĠCup': 968,
#  'ĠKali': 40843,
#  'ĠMovement': 11753,
#  'elect': 6930,
#  'Ġearliest': 13342,
#  'ĠPadres': 14965,
#  'Ġsteel': 3689,
#  'ĠMyanmar': 7095,
#  'ĠSamp': 18706,
#  'Ġpropri': 35740,
#  'ONES': 36145,
#  'Atlanta': 36974,
#  '804': 37413,
#  'ĠColumn': 32212,
#  'ĠStainless': 43522,
#  'Ġlaughed': 13503,
#  'Ġtake': 185,
#  'Ġhundreds': 2213,
#  'Ġraises': 7700,
#  'ĠSafe': 13793,
#  'Ġstainless': 23486,
#  'ĠSanskrit': 44018,
#  'Naz': 46016,
#  'diff': 32278,
#  'oxicity': 46513,
#  'izoph': 49560,
#  'both': 17143,
#  'Ġorganized': 5798,
#  'Ġmurdered': 9694,
#  'ĠEat': 21213,
#  'ĠNeon': 36349,
#  'Ġincompatible': 37228,
#  'Ġdeviation': 38369,
#  'Climate': 40466,
#  'ĠGPS': 11921,
#  'Ġram': 19634,
#  'ĠCorona': 28774,
#  'Ġuns': 9977,
#  'ĠCRC': 43444,
#  'Ġaccept': 3264,
#  'Ġcivil': 2366,
#  'Ġurges': 19288,
#  '251': 32306,
#  'later': 36600,
#  'ormal': 43808,
#  'Ġmonstrous': 34957,
#  'fo': 21466,
#  '03': 3933,
#  '855': 33450,
#  'Ġheadlined': 27724,
#  'traumatic': 30865,
#  'ĠCr': 5309,
#  'Ġaccessories': 10131,
#  'ĠCardiff': 12426,
#  'Ġstatement': 445,
#  'Ġatoms': 33310,
#  'ĠWarrant': 36732,
#  'Major': 37038,
#  'ĠCharm': 34959,
#  'Ġem': 2841,
#  'ĠPA': 5931,
#  'Ġstatue': 9577,
#  'Ġbatch': 14398,
#  'ĠKand': 26275,
#  'Ġcharacteristic': 26293,
#  'ĠBOOK': 39854,
#  'ĠResolution': 22565,
#  'ĠPathfinder': 45178,
#  'OIL': 41382,
#  'ĠUtilities': 21884,
#  'Ġcensus': 18023,
#  'Ġrepresentatives': 4844,
#  'Ġtimeframe': 24925,
#  'Ġinputs': 16584,
#  'itudes': 25917,
#  'Ġmasculine': 37360,
#  '776': 39402,
#  'Ġunm': 30780,
#  'Ġhidden': 7397,
#  'Kat': 27029,
#  'ĠComic': 20820,
#  'PLIC': 44597,
#  'ĠMisty': 38793,
#  'ĠFug': 34704,
#  'Ġelderly': 7497,
#  'Ġpaths': 14561,
#  'ols': 11925,
#  'vc': 36940,
#  'č': 50121,
#  'ifle': 30715,
#  'ording': 36473,
#  'ĠIran': 1603,
#  'aith': 22724,
#  'ought': 12807,
#  'Ġfuelled': 20972,
#  'Ġreflecting': 10811,
#  'gars': 14468,
#  'stood': 31935,
#  'ace': 4450,
#  'Ġdemonstr': 30673,
#  'Ġantigen': 44368,
#  'ija': 12733,
#  'ĠSELECT': 44664,
#  're': 241,
#  'gow': 32770,
#  'ĠEncounter': 44492,
#  'Ġchalleng': 49545,
#  'Ġsurvive': 6008,
#  'Ġbetrayed': 26913,
#  'Ġwines': 13921,
#  'Cont': 26412,
#  'mentioned': 39346,
#  'Ġoffering': 1839,
#  'Ġprogressing': 20307,
#  'Ġmerry': 35814,
#  'Ġpoetry': 14665,
#  'ĠLay': 15521,
#  'ĠRoads': 21201,
#  'Ġpian': 23674,
#  'izer': 6315,
#  'ãĥŃ': 49323,
#  'Ġgraded': 35175,
#  'ĠBasics': 42143,
#  'Ġsplendid': 35803,
#  'ĠTHANK': 42787,
#  'INESS': 28275,
#  'Ġessential': 4499,
#  'ovic': 4834,
#  'Ġspecialization': 44463,
#  'asia': 19036,
#  'Ġpollution': 6631,
#  'Ġstole': 8268,
#  'ĠCJ': 17468,
#  'ĠMerkel': 6580,
#  'ĠWired': 36572,
#  '668': 37867,
#  'Ġaim': 4374,
#  'clud': 47902,
#  'icker': 13917,
#  'ĠJon': 4160,
#  'Ġexcavation': 35525,
#  'Ġministerial': 22822,
#  'ignty': 45934,
#  '465': 33544,
#  'Tips': 46070,
#  'ĠWell': 2647,
#  'ĠPa': 5476,
#  'Ġhashes': 48231,
#  'Ġexploits': 25924,
#  'Ġtreatment': 1416,
#  'ils': 5290,
#  'ak': 677,
#  'Ġwheel': 5964,
#  'Ġobjection': 24763,
#  'Ġ1991': 9633,
#  'Ġwoman': 693,
#  'Ġsprint': 12631,
#  'Ġbaths': 28650,
#  'Ġcannon': 30941,
#  'telling': 31647,
#  'Ġaxis': 31799,
#  'Bang': 36929,
#  'Ġdexter': 48106,
#  'protein': 43092,
#  'ĠSparks': 22320,
#  'Anyone': 25480,
#  'CA': 4054,
#  'ccoli': 44247,
#  'Ġtodd': 46736,
#  'ä¸ī': 49442,
#  'Ġburnt': 18698,
#  'oral': 15010,
#  'billion': 9026,
#  'Ġtrenches': 32872,
#  "?'": 6600,
#  'ĠQur': 42878,
#  'Ġtowards': 1567,
#  'imir': 32850,
#  'ĠKurd': 41797,
#  'å£«': 49527,
#  'Ġproblem': 936,
#  'Ġpregnancy': 6690,
#  'antis': 22122,
#  'ocus': 23189,
#  'pse': 26731,
#  'ĠCyan': 45239,
#  'Ġconcerns': 1379,
#  'pec': 26512,
#  'ĠStra': 13893,
#  'ĠContent': 12803,
#  'Ġmillennium': 38751,
#  'Ġmm': 15408,
#  ')=(': 50016,
#  'ĠTakes': 29072,
#  'ĠTesla': 4919,
#  'Laughs': 39410,
#  'Ġcalibrated': 42422,
#  'ĠBonds': 23419,
#  'ĠWide': 19001,
#  'ĠWeasley': 48045,
#  'Ġoverlooked': 16042,
#  'pes': 29270,
#  'Ġangled': 39559,
#  'ĠTradition': 40880,
#  'Ġoutdated': 19363,
#  'Ġprox': 43860,
#  'Ġpatrols': 20315,
#  'Ġtuberculosis': 33695,
#  'Ġlymph': 23496,
#  'ĠCig': 38906,
#  '525': 29451,
#  'Mi': 39168,
#  'ecycle': 35296,
#  'Ġrobotic': 20701,
#  'ĠDefinitely': 33826,
#  'YouTube': 36169,
#  'ĠTsu': 42070,
#  'ĠMehran': 47956,
#  'cpp': 49317,
#  'do': 5016,
#  'Ġoverride': 30333,
#  'Ġtab': 12207,
#  'Davis': 36787,
#  'prem': 20692,
#  'ĠProvincial': 17684,
#  'rand': 22103,
#  'ĠCET': 39034,
#  'Ġspike': 12490,
#  'Ġomin': 43492,
#  'Ġwedd': 44398,
#  'Ġglances': 44333,
#  'mercial': 49140,
#  'Ġbacklog': 14846,
#  'usercontent': 49765,
#  'ĠPrincipal': 13619,
#  'dig': 20098,
#  'Ġugly': 11355,
#  'uctor': 42618,
#  'ĠBig': 1776,
#  'Ġmidfielder': 5732,
#  'Kal': 32604,
#  'ocese': 12074,
#  '529': 37261,
#  'crypt': 44675,
#  'ĠEmanuel': 18312,
#  'Ġgenerals': 25363,
#  'isman': 21581,
#  'hate': 33990,
#  'Ġ191': 31487,
#  'Ġpigeon': 38549,
#  'Ġthou': 44761,
#  'bsite': 46462,
#  'ĠEarth': 3875,
#  'Ġdonations': 5215,
#  'ĠBot': 13954,
#  'Ġconglomerate': 15814,
#  'ĠSans': 25450,
#  'Ġwaited': 9010,
#  'whelming': 26019,
#  'ĠCancel': 31543,
#  'Ġbreaths': 41711,
#  'itles': 46913,
#  'ĠSlack': 29124,
#  'Ġphantom': 43741,
#  'olescent': 43979,
#  'ran': 3917,
#  'Ġamongst': 9783,
#  'ĠNorris': 20164,
#  'ĠOpportunity': 19469,
#  'windows': 47748,
#  'Ġopposite': 5483,
#  'Ctrl': 48719,
#  'ĠMemorial': 4604,
#  'Ġconfinement': 25615,
#  'ĠHew': 16251,
#  'ĠNir': 28140,
#  'oscope': 31468,
#  'Ġgloomy': 32627,
#  'Ġcontrolling': 10568,
#  'feed': 18790,
#  'Ġ229': 26972,
#  'Ġrejuven': 26439,
#  'Ġresponded': 2334,
#  'Ġloophole': 30640,
#  'Ġhour': 1946,
#  'essor': 33728,
#  'inducing': 34909,
#  'Ġdangling': 34952,
#  'Ġseized': 5942,
#  'Ġservant': 20667,
#  'ĠStockholm': 18850,
#  'Ġsnatched': 25702,
#  'Michelle': 38268,
#  'ĠRapt': 38102,
#  'ĠAlberta': 6055,
#  'ederation': 41447,
#  'Ġpredator': 25293,
#  'Ġ301': 25895,
#  'Ġpathogens': 35904,
#  'Ġincarcer': 45606,
#  'Ġdorsal': 47152,
#  'í': 47649,
#  'ĠChick': 23569,
#  'ĠBacon': 26157,
#  'Snake': 47962,
#  'oire': 41154,
#  'Ġ($)': 41945,
#  'ĠGh': 5977,
#  'Ġeasily': 2773,
#  'Sports': 10554,
#  'ĠJill': 12893,
#  'ectar': 39459,
#  'Ġincon': 27493,
#  'ĠBread': 28722,
#  'Ġassoci': 40274,
#  'agan': 7060,
#  'Ġlightly': 14998,
#  'Frag': 47881,
#  'Ġscaling': 22187,
#  'Ġembarrassed': 17319,
#  'ĠWells': 6093,
#  'ĠPercentage': 34522,
#  'ĠCamden': 23752,
#  'mk': 43503,
#  'ĠManny': 20608,
#  'Ġsimmer': 25726,
#  'ĠGOOD': 31708,
#  'ĠPax': 37816,
#  'Wiki': 46929,
#  'dial': 43735,
#  'Ġhardest': 11111,
#  'endants': 35845,
#  'ĠScor': 40219,
#  'Gun': 39916,
#  'Ab': 13112,
#  'Ġrage': 14706,
#  'bas': 15609,
#  'Ġmosqu': 49209,
#  'Ġtuition': 12263,
#  'Ġadministrators': 11976,
#  'ĠOmar': 11482,
#  'Ġtreat': 3951,
#  'ĠLenin': 37632,
#  'idents': 22612,
#  'ĠLarge': 13769,
#  'ĠShakespeare': 16538,
#  'ĠBulgaria': 19848,
#  'ĠKend': 20611,
#  'lie': 11527,
#  'Ġecho': 23930,
#  'ĠRaiders': 6194,
#  'ĠRuler': 43493,
#  'Officials': 35779,
#  'Consider': 44311,
#  'Footnote': 49627,
#  'Ġreprodu': 37209,
#  'ĠSr': 8482,
#  'ified': 3786,
#  'Ġlawyers': 3969,
#  'Ġscreening': 7231,
#  'elman': 16955,
#  'Ġreasons': 2188,
#  'Ġhanding': 12785,
#  'ĠStephenson': 23047,
#  'UV': 31812,
#  'Ġpostage': 40225,
#  'ĠSgt': 9236,
#  'ĠJamal': 15327,
#  'ĠFurther': 7029,
#  'Ġappreciate': 5478,
#  'Ġhanging': 7209,
#  'ĠAndrea': 9929,
#  'ĠKag': 24803,
#  '309': 31573,
#  'ĠYoutube': 33530,
#  'Ġ=================================================================': 44793,
#  '"></': 49853,
#  'Ġmercy': 20222,
#  'ĠSimulator': 45765,
#  'Ġkidnapping': 12311,
#  'ĠWay': 4846,
#  'Ġpoised': 10137,
#  'Ġwarns': 14331,
#  'ĠReturn': 11968,
#  'Ġtrustworthy': 32101,
#  'Ġextract': 14660,
#  'ĠPiercing': 48579,
#  'Ġcrim': 29322,
#  'Ġemph': 29398,
#  'Ġseaw': 26996,
#  'ĠTRANS': 39995,
#  'Transaction': 48132,
#  'iu': 9060,
#  'puted': 29724,
#  'Ġhits': 2323,
#  '+++': 48845,
#  'ĠGilbert': 13667,
#  'Ġresent': 31379,
#  'Ġserum': 38994,
#  'Human': 33837,
#  'Ġcd': 45584,
#  'Ġvehicle': 1155,
#  'ĠKick': 16832,
#  'pt': 3320,
#  'fake': 18169,
#  'Ġlandowners': 26967,
#  'Ġcolonies': 28863,
#  'ĠFS': 21218,
#  'Ġcentimeters': 32454,
#  'Ġspear': 21106,
#  'Ġcautioned': 13335,
#  'By': 2765,
#  'ĠTIME': 18034,
#  'Ġsnippets': 39976,
#  'TPS': 45796,
#  'platform': 29912,
#  'Ġmattress': 24866,
#  'Ġunfor': 34262,
#  'Ġnew': 92,
#  'idable': 47551,
#  'ĠTropical': 18683,
#  'Ġviolin': 24896,
#  'Ġratified': 27504,
#  'ĠLAN': 32425,
#  'ĠFlat': 19920,
#  '767': 38504,
#  'Orderable': 50213,
#  'Skill': 47937,
#  'iosity': 45226,
#  'Ġdrastic': 19167,
#  'Ġequally': 6681,
#  'phys': 39409,
#  'Ġprism': 42641,
#  'heavy': 18888,
#  'distance': 27861,
#  'Cube': 44406,
#  '"],"': 44690,
#  'antam': 26287,
#  'ĠReaction': 39067,
#  'Ġdescribing': 9072,
#  'Ġrebounds': 3498,
#  'Ġtherapists': 32464,
#  'Ġchoking': 26864,
#  'Ġcollaborate': 16075,
#  'Ġembodies': 33434,
#  'Ġbreaking': 3433,
#  'Ġpitching': 9218,
#  'Ġuranium': 18734,
#  'ĠSting': 29157,
#  'ĠIlluminati': 46667,
#  'EL': 3721,
#  'Ġmes': 10969,
#  'ĠTeddy': 24169,
#  'Sov': 49246,
#  'Ġelement': 7510,
#  'Ġfinished': 1550,
#  'fail': 37694,
#  'ĠTurkey': 2769,
#  'Ġnature': 2574,
#  'ĠDaniel': 3028,
#  'Ġmentality': 14014,
#  ',.': 39747,
#  'Ġbulb': 32384,
#  'ĠRept': 46245,
#  'Ġcheek': 15401,
#  'Ġpartners': 2567,
#  'ira': 3578,
#  'ead': 19928,
#  'Ġ416': 34509,
#  'Ġvoc': 28312,
#  'iled': 6691,
#  'Ġz': 992,
#  'Ġrabbits': 33899,
#  'Ġagreement': 1288,
#  'Ġdisciplinary': 13999,
#  'Ġsurrounds': 29010,
#  'Ġtenets': 38218,
#  'ĠSherman': 13226,
#  'Ġwretched': 42824,
#  'æ©Ł': 49449,
#  'Ġflagship': 8589,
#  'ĠSpark': 20255,
#  'ĠNAFTA': 13783,
#  'Ġ180': 8963,
#  'Ġfatally': 11293,
#  'Ġfreed': 14313,
#  'ĠConnie': 26113,
#  'payment': 28825,
#  'ages': 3443,
#  'arg': 5384,
#  'oka': 12999,
#  'Ġwelcomes': 16795,
#  'Ġsocieties': 17537,
#  'ĠTamil': 12634,
#  'Ġvitamins': 26656,
#  'Ġmantle': 30849,
#  'Du': 34965,
#  'Ġalgorith': 43448,
#  'ĠMormonism': 47913,
#  'Runner': 45163,
#  'ĠAvalanche': 22996,
#  'oliberal': 47520,
#  'Ġimmoral': 33231,
#  'ĠUri': 35034,
#  'ĠTina': 15720,
#  'ĠPhilippines': 5639,
#  'Support': 38873,
#  'Magikarp': 49879,
#  'Ġunanswered': 20358,
#  'Connell': 28317,
#  'Ġidi': 43063,
#  'Ġresp': 18237,
#  'oche': 18339,
#  'Ġsatisfaction': 11658,
#  '189': 28945,
#  'Ġdeferred': 16899,
#  'Ġpartake': 37404,
#  'yellow': 34103,
#  'ĠCly': 30194,
#  'Ġparticipating': 6051,
#  'TRY': 37956,
#  'inding': 24088,
#  'ĠWes': 15590,
#  'writ': 42002,
#  'gr': 6504,
#  'ĠAlic': 43679,
#  'Ġsense': 1472,
#  'Ġpopular': 1406,
#  'ĠWillow': 22096,
#  'Ġrelegated': 23101,
#  'automatic': 27106,
#  'ĠPas': 11920,
#  'uned': 37236,
#  'ĠMono': 44512,
#  'bee': 14650,
#  'Ġhavens': 31579,
#  'Ġtabs': 26249,
#  '243': 30320,
#  'Ġmouth': 6085,
#  'Ġhugged': 27425,
#  'mod': 14377,
#  'ĠAbsolutely': 23743,
#  'ĠALS': 31252,
#  'Ġfingertips': 33138,
#  'Gall': 42691,
#  'Ġplur': 46005,
#  "Ġ'.": 48694,
#  'ilty': 33576,
#  'Ġglove': 19015,
#  'ĠDoor': 21405,
#  'Ġscripts': 26878,
#  'Ġaged': 5180,
#  'ĠUE': 37084,
#  'Ġcondom': 37320,
#  'ĠGarden': 6081,
#  '35': 2022,
#  've': 548,
#  'ĠBank': 788,
#  'Live': 16549,
#  'ĠMerge': 46417,
#  'Ġrelief': 3500,
#  'ailed': 13355,
#  'Ġtimid': 39649,
#  'Ġnewsp': 48933,
#  'BOOK': 27614,
#  'Ġsquadron': 40261,
#  'Ġdate': 1248,
#  'Ġgraduated': 8505,
#  'Those': 11195,
#  'ĠLikewise': 21371,
#  'enses': 21526,
#  'yi': 28831,
#  'Ġdetrimental': 23883,
#  'Ġrelationships': 4158,
#  'ĠRoy': 5470,
#  'Ġprolong': 27514,
#  'practice': 32524,
#  'itiveness': 43468,
#  'Ġrenew': 11007,
#  'Port': 22117,
#  '797': 40065,
#  'Ġretarded': 47304,
#  'Ġsigh': 27305,
#  'ĠDarwin': 24458,
#  'wm': 43237,
#  'uchin': 15895,
#  'ĠPorn': 37033,
#  'arch': 13161,
#  'Soviet': 37284,
#  'Ġcosting': 15135,
#  'Ġexcise': 28994,
#  'ĠOutlook': 11011,
#  'ĠAtkins': 24885,
#  'èĥ': 48620,
#  'ĠIowa': 4109,
#  'ĠTool': 25251,
#  'ĠDestiny': 23313,
#  'Ġdr': 12402,
#  'Ġmach': 20399,
#  'ĠLords': 26608,
#  'izzard': 29549,
#  'gaard': 25039,
#  'ĠSawyer': 29644,
#  'Ġpessimistic': 32415,
#  '.:': 12651,
#  '463': 36611,
#  'bf': 36920,
#  'ĠQt': 46603,
#  'ukemia': 44336,
#  'Ġdozens': 4295,
#  'Ġwhoever': 14051,
#  'Ġnonviolent': 36887,
#  'Ġparallel': 12980,
#  'ĠWis': 15676,
#  'phi': 32079,
#  'ĠTyphoon': 33132,
#  '.\'"': 9957,
#  'ĠAllah': 20788,
#  'vind': 27501,
#  'Ġpaced': 28668,
#  'lat': 12805,
#  'Ġreduced': 2906,
#  'ips': 7418,
#  'ĠSeason': 5446,
#  'ĠFle': 12602,
#  'Ġvanished': 22147,
#  'Ġ210': 18661,
#  'Ġalleges': 11413,
#  'Ġbouts': 24750,
#  'Ġunavailable': 19216,
#  'ĠCorporation': 2824,
#  'relations': 36275,
#  'aba': 6412,
#  'Ġcarrier': 6994,
#  'ĠAgain': 7574,
#  'Ġundermined': 21167,
#  'ĠUniv': 35232,
#  'anchez': 43525,
#  'DON': 42737,
#  'neum': 45042,
#  'Ġdeparture': 5824,
#  'ĠMod': 10274,
#  'Java': 32379,
#  'Ġbravery': 24895,
#  'ĠIdeally': 34793,
#  'Ġamused': 36530,
#  'ĠCommentary': 40070,
#  'issors': 45937,
#  'ipment': 39737,
#  'Ġrein': 9493,
#  'ĠRally': 20918,
#  'ĠHyd': 24893,
#  '10000': 47303,
#  'ĠChrist': 4845,
#  'Ġcommemor': 16293,
#  'ABLE': 13732,
#  'Ġintimidate': 27914,
#  'span': 36407,
#  'ĠCust': 37513,
#  'zona': 45954,
#  'vin': 6320,
#  'plan': 11181,
#  'Ġnursing': 8701,
#  'io': 1020,
#  'Ġequivalent': 6305,
#  'ĠFranchise': 35130,
#  'ĠSydney': 4290,
#  '2020': 24837,
#  'Ġvenerable': 38162,
#  'Nobody': 18975,
#  'ride': 23167,
#  'ĠConvert': 32988,
#  'ĠMOD': 35179,
#  'ĠDrag': 11588,
#  'Ġswallow': 26124,
#  'Ġ364': 38930,
#  'Ġhair': 2549,
#  'Ġwarmth': 20310,
#  'travel': 28881,
#  'ĠHindi': 19840,
#  'Ġperformers': 10300,
#  'ĠFriedrich': 36960,
#  'voy': 35246,
#  'Ġmole': 39120,
#  'Ġcalendar': 7127,
#  'Ġ+/-': 44832,
#  'regon': 46670,
#  'aceae': 47334,
#  'Matrix': 47360,
#  'Ġfilthy': 35200,
#  'endiary': 48314,
#  'Ġclaims': 1449,
#  'Ġevolved': 12236,
#  'ĠANY': 16005,
#  'Ġsupported': 2800,
#  'mission': 12478,
#  ':': 35,
#  'ĠMaharashtra': 14729,
#  'ĠMonitor': 23328,
#  'Ġlaw': 488,
#  'Allen': 32291,
#  'Ġpleading': 17532,
#  'racist': 35969,
#  'Oak': 36043,
#  'burn': 7554,
#  'killers': 27621,
#  'Ġonward': 36505,
#  'interpret': 41111,
#  'Ġexample': 1246,
#  'OGR': 41716,
#  'ĠSTD': 41840,
#  'ĠGears': 45079,
#  'ĠShen': 12242,
#  'ĠPrel': 26449,
#  'Ġhistorians': 26893,
#  'iewicz': 31735,
#  'iques': 16474,
#  'ĠGerrard': 28822,
#  'Background': 48277,
#  'Sexual': 44598,
#  '_>': 49982,
#  'ĠHighland': 16477,
#  'Ġslur': 29118,
#  'ĠAaron': 4802,
#  'Ġelbow': 13789,
#  'ĠExec': 20297,
#  'pelled': 30514,
#  'ches': 5559,
#  'ĠLevy': 20051,
#  'definition': 38835,
#  'Ġwaterproof': 28126,
#  'per': 1741,
#  'Ġbankers': 13432,
#  'laws': 18712,
#  'Ġdads': 30173,
#  'Ġambiguity': 35566,
#  'necessary': 37798,
#  'Tomorrow': 38849,
#  'Pen': 32884,
#  'Ġdominance': 12532,
#  'Ġaddiction': 7530,
#  'Â°': 12938,
#  'Ġcac': 33624,
#  'zza': 19670,
#  'Ġtroublesome': 34056,
#  'ĠNewman': 13614,
#  'Ext': 40884,
#  'ĠScrew': 42667,
#  'ĠFOIA': 43695,
#  'Ġforging': 29394,
#  'Ġkil': 12868,
#  'yards': 17230,
#  'Fin': 34027,
#  'not': 3654,
#  'Ġfrying': 38571,
#  'helps': 44590,
#  'Ġmonop': 46547,
#  'ĠMamm': 29838,
#  'Ġisot': 40640,
#  'ĠBarbar': 40482,
#  'ĠVoice': 10880,
#  'ĠMortal': 44762,
#  'Ġorganizational': 20973,
#  'ĠShaun': 16065,
#  'special': 19423,
#  'ĠLynn': 9840,
#  'Ġflagged': 17253,
#  'NM': 31156,
#  'ĠTate': 16255,
#  'Ir': 34547,
#  'Party': 38210,
#  'Ġreaches': 11541,
#  'Ġquarrel': 39486,
#  'Ġanxiety': 6882,
#  'ĠTEST': 41759,
#  'ife': 11819,
#  'odan': 44892,
#  'ĠDocuments': 32682,
#  'Ġspears': 45139,
#  'NPR': 39673,
#  'Ġpatriarchy': 40939,
#  'ller': 12853,
#  'ĠSuicide': 25053,
#  'Ġcontinued': 1143,
#  'reement': 43563,
#  'Rail': 36458,
#  'uz': 4987,
#  'asions': 38258,
#  'ĠUT': 14019,
#  'ĠcafÃ©': 26059,
#  'Ġhyd': 13075,
#  'Ġmph': 2395,
#  'ĠRichmond': 7851,
#  'ĠColumbia': 4635,
#  'Ġsummar': 39186,
#  'essage': 49528,
#  'ĠDNC': 22252,
#  'ĠExcel': 27241,
#  'Trump': 7565,
#  '355': 29794,
#  'Ġphenomenon': 10632,
#  'Ġtimes': 498,
#  'Ġmoderately': 30389,
#  'Ġfiasco': 33512,
#  '647': 36603,
#  'orate': 28590,
#  'ription': 49468,
#  'Ġplant': 2195,
#  'Ġ138': 21436,
#  'Ġwaterfall': 35076,
#  'non': 13424,
#  'ĠTanner': 20504,
#  'Ġcling': 32645,
#  'avoid': 40623,
#  'ĠTir': 19801,
#  'LOCK': 45268,
#  'Ġproper': 4692,
#  'Ġfragile': 14283,
#  'Ġdoses': 19899,
#  'Ġterms': 1110,
#  'Ġcaravan': 15987,
#  'Ġnortheastern': 17406,
#  'ĠLer': 23813,
#  'Ġcuts': 2599,
#  'sa': 11146,
#  'TW': 29334,
#  ...}

# %%
# Import necessary libraries
from transformers import AutoTokenizer, AutoModelForTokenClassification, Trainer, TrainingArguments
import evaluate
import torch

# Define and load the tokenizer and dataset
tokenizer = AutoTokenizer.from_pretrained('lakshyakh93/deberta_finetuned_pii')
train_set1_selected = train_set1.select(range(5))

# Define label mapping
# label_map = {'O': 0, 'TIME': 1, 'DATE': 2, 'LASTNAME1': 3, 'LASTNAME2': 4, 'EMAIL': 5, 'SOCIALNUMBER': 6}
label_map = {'O': 0, 'FIRSTNAME_1': 1, 'LASTNAME_1': 2, 'EMAIL_1': 3, 'PHONENUMBER_1': 4, 'SSN_1': 5, 'JOBTITLE_1': 6,
             'SEX_1': 7, 'BUILDINGNUMBER_1': 8, 'STREET_1': 9, 'DOB_1': 10, 'USERNAME_1': 11, 'AGE_1': 12,
             'PREFIX_1': 13, 'ACCOUNTNUMBER_1': 14}


# Function to tokenize and align labels
def tokenize_and_align_labels(example):
    tokenized_inputs = tokenizer(example['source_text'], truncation=True, padding='max_length', max_length=512)
    # tokenized_inputs = tokenizer(example['unmasked_text'], truncation=True, padding='max_length', max_length=512)
    labels = ['O'] * len(tokenized_inputs['input_ids'])
    
    # Adjust indexing to fit the tokenization
    example['source_text'] = example['source_text'][:512]  # Ensure source_text matches max_length
    # example['unmasked_text'] = example['unmasked_text'][:512]  # Ensure source_text matches max_length

    for span in example['privacy_mask']:
    # for span in example['masked_text']:
        # start, end, label_name = span['start'], span['end'], span['label']
        # label_id = label_map.get(label_name, 0)
        
        # # span_tokens = tokenizer(example['source_text'][start:end], add_special_tokens=False).tokens()
        # span_tokens = tokenizer(example['unmasked_text'][start:end], add_special_tokens=False).tokens()

        # # Properly create and align labels (assuming BERT tokenizer)
        # for i, token in enumerate(tokenized_inputs.tokens()):
        #     if token in span_tokens:
        #         labels[i] = label_id

        if isinstance(span, dict):  # Proceed only if `span` is a dictionary
            print(type(example['privacy_mask']))
            start, end, label_name = span['start'], span['end'], span['label']
            label_id = label_map.get(label_name, 0)
            
            # Tokenize the substring from `unmasked_text`
            span_tokens = tokenizer(example['unmasked_text'][start:end], add_special_tokens=False).tokens()

        # Align labels for tokens in `span_tokens`
            for i, token in enumerate(tokenized_inputs.tokens()):
                if token in span_tokens:
                    labels[i] = label_id
        else:
            print("Expected a dictionary but got:", span)

    numeric_labels = [label_map.get(label, -100) for label in labels]
    numeric_labels += [-100] * (len(tokenized_inputs['input_ids']) - len(numeric_labels))
    
    tokenized_inputs['labels'] = numeric_labels
    return tokenized_inputs


# Apply function to dataset
encoded_dataset = train_set1_selected.map(tokenize_and_align_labels, batched=False)
# encoded_dataset = train_set2.map(tokenize_and_align_labels, batched=False)

# Convert to PyTorch tensors
input_ids = torch.tensor(encoded_dataset['input_ids'])
attention_mask = torch.tensor(encoded_dataset['attention_mask'])
labels = torch.tensor(encoded_dataset['labels'])

# Load model
model = AutoModelForTokenClassification.from_pretrained('lakshyakh93/deberta_finetuned_pii')

# Define metric computation
metric = evaluate.load('accuracy')  # You may want to load relevant metrics for token classification

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=2)  # Note: axis=2 for token classification
    true_labels = labels != -100  # Masking out unnecessary labels
    
    # Flatten predictions and true_labels to compute accuracy
    flattened_predictions = predictions[true_labels]
    flattened_labels = labels[true_labels]
    
    results = metric.compute(references=flattened_labels, predictions=flattened_predictions)
    return results


# Tokenize validation set
small_val = val_set.shuffle(seed=123).select(range(5))
encoded_small_val = small_val.map(tokenize_and_align_labels, batched=False)

# Training arguments
train_args = TrainingArguments(
    output_dir='./results',
    evaluation_strategy='epoch',
    per_device_train_batch_size=8,
    num_train_epochs=3,
    learning_rate=5e-2,
    weight_decay=0.01,
    logging_steps=10,
    save_steps=10,
    eval_steps=10,
    gradient_accumulation_steps=2,  # Adjust if needed
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=train_args,
    train_dataset=encoded_dataset,
    eval_dataset=encoded_small_val,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)
# Out:
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# <class 'list'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 63
#      59     return tokenized_inputs
#      62 # Apply function to dataset
# ---> 63 encoded_dataset = train_set1_selected.map(tokenize_and_align_labels, batched=False)
#      64 # encoded_dataset = train_set2.map(tokenize_and_align_labels, batched=False)
#      65
#      66 # Convert to PyTorch tensors
#      67 input_ids = torch.tensor(encoded_dataset['input_ids'])
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:602, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     600     self: "Dataset" = kwargs.pop("self")
#     601 # apply actual function
# --> 602 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     603 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     604 for dataset in datasets:
#     605     # Remove task templates if a column mapping of the template is no longer valid
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:567, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     560 self_format = {
#     561     "type": self._format_type,
#     562     "format_kwargs": self._format_kwargs,
#     563     "columns": self._format_columns,
#     564     "output_all_columns": self._output_all_columns,
#     565 }
#     566 # apply actual function
# --> 567 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     568 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     569 # re-apply format to the output
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:3167, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3161 if transformed_dataset is None:
#    3162     with hf_tqdm(
#    3163         unit=" examples",
#    3164         total=pbar_total,
#    3165         desc=desc or "Map",
#    3166     ) as pbar:
# -> 3167         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3168             if done:
#    3169                 shards_done += 1
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:3528, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3526 _time = time.time()
#    3527 for i, example in shard_iterable:
# -> 3528     example = apply_function_on_filtered_inputs(example, i, offset=offset)
#    3529     if update_data:
#    3530         if i == 0:
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:3427, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3425 if with_rank:
#    3426     additional_args += (rank,)
# -> 3427 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3428 if isinstance(processed_inputs, LazyDict):
#    3429     processed_inputs = {
#    3430         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3431     }
#
# Cell In[43], line 46, in tokenize_and_align_labels(example)
#      43     label_id = label_map.get(label_name, 0)
#      45     # Tokenize the substring from `unmasked_text`
# ---> 46     span_tokens = tokenizer(example['unmasked_text'][start:end], add_special_tokens=False).tokens()
#      48 # Align labels for tokens in `span_tokens`
#      49     for i, token in enumerate(tokenized_inputs.tokens()):
#
# File c:\Users\JoyChang\anaconda3\Lib\site-packages\datasets\formatting\formatting.py:277, in LazyDict.__getitem__(self, key)
#     276 def __getitem__(self, key):
# --> 277     value = self.data[key]
#     278     if key in self.keys_to_format:
#     279         value = self.format(key)
#
# KeyError: 'unmasked_text'

# %%
# Run training
trainer.train()
# Out:
#  33%|███▎      | 1/3 [00:42<01:24, 42.44s/it]
#  33%|███▎      | 1/3 [00:56<01:24, 42.44s/it]
# {'eval_loss': 11.556055068969727, 'eval_accuracy': 0.0, 'eval_runtime': 13.9542, 'eval_samples_per_second': 0.358, 'eval_steps_per_second': 0.072, 'epoch': 1.0}

# %%
trainer.evaluate()
# Out:
# 100%|██████████| 2/2 [00:04<00:00,  2.25s/it]
# {'eval_loss': 0.0,
#  'eval_accuracy': 1.0,
#  'eval_runtime': 22.0797,
#  'eval_samples_per_second': 0.453,
#  'eval_steps_per_second': 0.091,
#  'epoch': 3.0}

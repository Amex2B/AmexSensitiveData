# %%
import os
import pandas as pd

# %%
filepath = os.path.join(os.getcwd(), 'data', 'extracted_tel_numbers_english_updated.csv')

# Read the CSV file using pandas
df = pd.read_csv(filepath)

# %%
sample_df = df[635:735]

# %%
# sample_df = sample_df.drop('Unnamed: 0', axis=1)
sample_df
# Out:
#                                          unmasked_text  \
# 635  Internship payments would be made in Australia...
# 636  Let's protect our intellectual property rights...
# 637  Dear Lamar Sage,\r\nWe would like to inform yo...
# 638  Hey Wilfred, did you remember to pay the cours...
# 639  Mrs. Hayden Jaden Wolf, a Cisgender woman of 6...
# ..                                                 ...
# 730  Please see attached the invoice of our subscri...
# 731  Dear Cis female, we identified an IP 7cec:e0fa...
# 732  I am Bradley from the Infrastructure departmen...
# 733  We got a request for an oncology consultation ...
# 734  I have some questions for Elyssa Purdy who was...
#
#                                            masked_text    phone_number target
# 635  Internship payments would be made in [CURRENCY...    037 983.1348    TEL
# 636  Let's protect our intellectual property rights...     084-0352145      O
# ...

# %%
filepath = os.path.join(os.getcwd(), 'data', 'joy_mini_df_tel.csv')
sample_df.to_csv(filepath)
